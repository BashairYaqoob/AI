# %%
# %pip install seaborn matplotlib scikit-learn
# Out:
# Collecting seaborn
#   Downloading seaborn-0.13.2-py3-none-any.whl.metadata (5.4 kB)
# Collecting matplotlib
#   Downloading matplotlib-3.10.8-cp312-cp312-win_amd64.whl.metadata (52 kB)
# Requirement already satisfied: scikit-learn in d:\onedrive\documents\ai\venv\lib\site-packages (1.8.0)
# Requirement already satisfied: numpy!=1.24.0,>=1.20 in d:\onedrive\documents\ai\venv\lib\site-packages (from seaborn) (2.4.3)
# Requirement already satisfied: pandas>=1.2 in d:\onedrive\documents\ai\venv\lib\site-packages (from seaborn) (3.0.1)
# Collecting contourpy>=1.0.1 (from matplotlib)
#   Downloading contourpy-1.3.3-cp312-cp312-win_amd64.whl.metadata (5.5 kB)
# Collecting cycler>=0.10 (from matplotlib)
#   Downloading cycler-0.12.1-py3-none-any.whl.metadata (3.8 kB)
# Collecting fonttools>=4.22.0 (from matplotlib)
#   Downloading fonttools-4.62.1-cp312-cp312-win_amd64.whl.metadata (119 kB)
# Collecting kiwisolver>=1.3.1 (from matplotlib)
#   Downloading kiwisolver-1.5.0-cp312-cp312-win_amd64.whl.metadata (5.2 kB)
# Requirement already satisfied: packaging>=20.0 in d:\onedrive\documents\ai\venv\lib\site-packages (from matplotlib) (26.0)
# Collecting pillow>=8 (from matplotlib)
#   Downloading pillow-12.2.0-cp312-cp312-win_amd64.whl.metadata (9.0 kB)
# Requirement already satisfied: pyparsing>=3 in d:\onedrive\documents\ai\venv\lib\site-packages (from matplotlib) (3.3.2)
# Requirement already satisfied: python-dateutil>=2.7 in d:\onedrive\documents\ai\venv\lib\site-packages (from matplotlib) (2.9.0.post0)
# Requirement already satisfied: scipy>=1.10.0 in d:\onedrive\documents\ai\venv\lib\site-packages (from scikit-learn) (1.17.1)
# Requirement already satisfied: joblib>=1.3.0 in d:\onedrive\documents\ai\venv\lib\site-packages (from scikit-learn) (1.5.3)
# Requirement already satisfied: threadpoolctl>=3.2.0 in d:\onedrive\documents\ai\venv\lib\site-packages (from scikit-learn) (3.6.0)
# Requirement already satisfied: tzdata in d:\onedrive\documents\ai\venv\lib\site-packages (from pandas>=1.2->seaborn) (2025.3)
# Requirement already satisfied: six>=1.5 in d:\onedrive\documents\ai\venv\lib\site-packages (from python-dateutil>=2.7->matplotlib) (1.17.0)
# Downloading seaborn-0.13.2-py3-none-any.whl (294 kB)
# Downloading matplotlib-3.10.8-cp312-cp312-win_amd64.whl (8.1 MB)
#    ---------------------------------------- 0.0/8.1 MB ? eta -:--:--
#    --- ------------------------------------ 0.8/8.1 MB 5.6 MB/s eta 0:00:02
#    --------- ------------------------------ 1.8/8.1 MB 5.3 MB/s eta 0:00:02
#    ----------- ---------------------------- 2.4/8.1 MB 3.8 MB/s eta 0:00:02
#    ------------ --------------------------- 2.6/8.1 MB 3.7 MB/s eta 0:00:02
#    --------------- ------------------------ 3.1/8.1 MB 3.0 MB/s eta 0:00:02
#    ---------------- ----------------------- 3.4/8.1 MB 2.9 MB/s eta 0:00:02
#    ------------------ --------------------- 3.7/8.1 MB 2.9 MB/s eta 0:00:02
#    -------------------- ------------------- 4.2/8.1 MB 2.6 MB/s eta 0:00:02
#    ----------------------- ---------------- 4.7/8.1 MB 2.5 MB/s eta 0:00:02
#    ------------------------ --------------- 5.0/8.1 MB 2.5 MB/s eta 0:00:02
#    ------------------------- -------------- 5.2/8.1 MB 2.3 MB/s eta 0:00:02
#    ---------------------------- ----------- 5.8/8.1 MB 2.2 MB/s eta 0:00:02
#    ------------------------------ --------- 6.3/8.1 MB 2.3 MB/s eta 0:00:01
#    -------------------------------- ------- 6.6/8.1 MB 2.2 MB/s eta 0:00:01
#    --------------------------------- ------ 6.8/8.1 MB 2.2 MB/s eta 0:00:01
#    ---------------------------------- ----- 7.1/8.1 MB 2.1 MB/s eta 0:00:01
#    ------------------------------------ --- 7.3/8.1 MB 2.1 MB/s eta 0:00:01
#    -------------------------------------- - 7.9/8.1 MB 2.0 MB/s eta 0:00:01
#    ---------------------------------------- 8.1/8.1 MB 2.0 MB/s eta 0:00:00
# Downloading contourpy-1.3.3-cp312-cp312-win_amd64.whl (226 kB)
# Downloading cycler-0.12.1-py3-none-any.whl (8.3 kB)
# Downloading fonttools-4.62.1-cp312-cp312-win_amd64.whl (2.3 MB)
#    ---------------------------------------- 0.0/2.3 MB ? eta -:--:--
#    ---- ----------------------------------- 0.3/2.3 MB ? eta -:--:--
#    ------------- -------------------------- 0.8/2.3 MB 2.2 MB/s eta 0:00:01
#    ---------------------- ----------------- 1.3/2.3 MB 2.5 MB/s eta 0:00:01
#    ------------------------------- -------- 1.8/2.3 MB 2.5 MB/s eta 0:00:01
#    ---------------------------------------- 2.3/2.3 MB 2.5 MB/s eta 0:00:00
# Downloading kiwisolver-1.5.0-cp312-cp312-win_amd64.whl (73 kB)
# Downloading pillow-12.2.0-cp312-cp312-win_amd64.whl (7.1 MB)
#    ---------------------------------------- 0.0/7.1 MB ? eta -:--:--
#    - -------------------------------------- 0.3/7.1 MB ? eta -:--:--
#    ---- ----------------------------------- 0.8/7.1 MB 2.1 MB/s eta 0:00:04
#    ----- ---------------------------------- 1.0/7.1 MB 1.8 MB/s eta 0:00:04
#    ------- -------------------------------- 1.3/7.1 MB 1.7 MB/s eta 0:00:04
#    -------- ------------------------------- 1.6/7.1 MB 1.6 MB/s eta 0:00:04
#    ----------- ---------------------------- 2.1/7.1 MB 1.7 MB/s eta 0:00:03
#    ------------- -------------------------- 2.4/7.1 MB 1.7 MB/s eta 0:00:03
#    ---------------- ----------------------- 2.9/7.1 MB 1.7 MB/s eta 0:00:03
#    ------------------- -------------------- 3.4/7.1 MB 1.8 MB/s eta 0:00:03
#    ---------------------- ----------------- 3.9/7.1 MB 1.8 MB/s eta 0:00:02
#    ----------------------- ---------------- 4.2/7.1 MB 1.8 MB/s eta 0:00:02
#    ------------------------- -------------- 4.5/7.1 MB 1.7 MB/s eta 0:00:02
#    -------------------------- ------------- 4.7/7.1 MB 1.7 MB/s eta 0:00:02
#    ---------------------------- ----------- 5.0/7.1 MB 1.7 MB/s eta 0:00:02
#    ----------------------------- ---------- 5.2/7.1 MB 1.7 MB/s eta 0:00:02
#    -------------------------------- ------- 5.8/7.1 MB 1.7 MB/s eta 0:00:01
#    ---------------------------------- ----- 6.0/7.1 MB 1.7 MB/s eta 0:00:01
#    ------------------------------------- -- 6.6/7.1 MB 1.7 MB/s eta 0:00:01
#    ---------------------------------------  7.1/7.1 MB 1.7 MB/s eta 0:00:01
#    ---------------------------------------- 7.1/7.1 MB 1.7 MB/s eta 0:00:00
# Installing collected packages: pillow, kiwisolver, fonttools, cycler, contourpy, matplotlib, seaborn
# Successfully installed contourpy-1.3.3 cycler-0.12.1 fonttools-4.62.1 kiwisolver-1.5.0 matplotlib-3.10.8 pillow-12.2.0 seaborn-0.13.2
# Note: you may need to restart the kernel to use updated packages.
# [notice] A new release of pip is available: 24.2 -> 26.0.1
# [notice] To update, run: python.exe -m pip install --upgrade pip

# %%
# Task 1 with dummy dataset
import pandas as pd
import numpy as np
from sklearn.model_selection import train_test_split
from sklearn.linear_model import LinearRegression
from sklearn.metrics import mean_squared_error, r2_score

data = {
    "square_footage": np.random.randint(500, 4000, 100),
    "bedrooms": np.random.randint(1, 6, 100),
    "bathrooms": np.random.randint(1, 4, 100),
    "age": np.random.randint(0, 30, 100),
    "price": np.random.randint(100000, 500000, 100)
}

df = pd.DataFrame(data)

X = df.drop("price", axis=1)
y = df["price"]

X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.2)

model = LinearRegression()
model.fit(X_train, y_train)
y_pred = model.predict(X_test)

print("MSE:", mean_squared_error(y_test, y_pred))
print("R2:", r2_score(y_test, y_pred))
new_house = [[2000, 3, 2, 5]]
print("Predicted Price:", model.predict(new_house)[0])
# Out:
# MSE: 15793182395.860394
# R2: -0.0793612786344704
# Predicted Price: 298701.79959891806
# d:\OneDrive\Documents\AI\venv\Lib\site-packages\sklearn\utils\validation.py:2691: UserWarning: X does not have valid feature names, but LinearRegression was fitted with feature names
#   warnings.warn(

# %%
#Task 2 assuming data set is in a file email.csv
import pandas as pd
from sklearn.model_selection import train_test_split
from sklearn.feature_extraction.text import TfidfVectorizer
from sklearn.linear_model import LogisticRegression
from sklearn.metrics import accuracy_score, classification_report

df = pd.read_csv("emails.csv")

df = df.dropna()

X = df["text"]
y = df["label"]

vectorizer = TfidfVectorizer(stop_words="english")
X = vectorizer.fit_transform(X)
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.2)

model = LogisticRegression()
model.fit(X_train, y_train)

y_pred = model.predict(X_test)
print("Accuracy:", accuracy_score(y_test, y_pred))
print(classification_report(y_test, y_pred))

new_email = ["Congratulations! You won a free iPhone. Click here now"]
new_email_vec = vectorizer.transform(new_email)

prediction = model.predict(new_email_vec)
print("Spam (1) or Not Spam (0):", prediction[0])

# %%
#Task 3
import pandas as pd
from sklearn.model_selection import train_test_split
from sklearn.preprocessing import StandardScaler
from sklearn.svm import SVC
from sklearn.metrics import accuracy_score

df = pd.read_csv("Heart.csv")

# Drop missing
df = df.dropna()

# Convert target
df["AHD"] = df["AHD"].map({"Yes": 1, "No": 0})

# 🔥 Encode categorical columns
categorical_cols = ["ChestPain", "Thal"]

df = pd.get_dummies(df, columns=categorical_cols, drop_first=True)

# Features & target
X = df.drop("AHD", axis=1)
y = df["AHD"]

# Scale
scaler = StandardScaler()
X = scaler.fit_transform(X)

# Split
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.2)

# Model (SVM)
model = SVC(kernel='linear')
model.fit(X_train, y_train)

# Evaluate
y_pred = model.predict(X_test)
print("Accuracy:", accuracy_score(y_test, y_pred))

# Hyperplane
print("Weights:", model.coef_)
print("Intercept:", model.intercept_)
# Out:
# Accuracy: 0.8833333333333333
# Weights: [[ 0.23236705 -0.15840356  0.3163209   0.25436197  0.06778008 -0.02834175
#    0.17532642 -0.32428309  0.27185002  0.55850303  0.11376684  0.73475939
#   -0.52117272 -0.20671672 -0.57805376 -0.3000697   0.306327  ]]
# Intercept: [-0.04022486]
